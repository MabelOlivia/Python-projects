# %%
import numpy as np
import pandas as pd
import os
import urllib
# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")

# %%
os.makedirs(file_path,exist_ok=True)
csv_path = os.path.join(file_path, "WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x16f057b2d30>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#       Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0        2020-01-03            AF  Afghanistan        EMRO           0
# 1        2020-01-04            AF  Afghanistan        EMRO           0
# 2        2020-01-05            AF  Afghanistan        EMRO           0
# 3        2020-01-06            AF  Afghanistan        EMRO           0
# 4        2020-01-07            AF  Afghanistan        EMRO           0
# ...             ...           ...          ...         ...         ...
# 67675    2020-10-12            ZW     Zimbabwe        AFRO          17
# 67676    2020-10-13            ZW     Zimbabwe        AFRO          10
# 67677    2020-10-14            ZW     Zimbabwe        AFRO          15
# 67678    2020-10-15            ZW     Zimbabwe        AFRO          19
# 67679    2020-10-16            ZW     Zimbabwe        AFRO          20
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=67680, step=1)

# %%
df.columns
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
g = df.groupby(" Country")
g

# %%
for country, country_df in g:
    print(country)
    print(country_df)
# Out:
# Afghanistan
#     Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0      2020-01-03            AF  Afghanistan        EMRO           0
# 1      2020-01-04            AF  Afghanistan        EMRO           0
# 2      2020-01-05            AF  Afghanistan        EMRO           0
# 3      2020-01-06            AF  Afghanistan        EMRO           0
# 4      2020-01-07            AF  Afghanistan        EMRO           0
# ..            ...           ...          ...         ...         ...
# 283    2020-10-12            AF  Afghanistan        EMRO           0
# 284    2020-10-13            AF  Afghanistan        EMRO         129
# 285    2020-10-14            AF  Afghanistan        EMRO           0
# 286    2020-10-15            AF  Afghanistan        EMRO          66
# 287    2020-10-16            AF  Afghanistan        EMRO          32
#
#       Cumulative_cases   New_deaths   Cumulative_deaths
# 0                    0            0                   0
# ...

# %%
df.index.values
# Out:
# array([    0,     1,     2, ..., 67677, 67678, 67679], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2020-10-14', 'ZW', 'Zimbabwe', ..., 8036, 0, 230],
#        ['2020-10-15', 'ZW', 'Zimbabwe', ..., 8055, 1, 231],
#        ['2020-10-16', 'ZW', 'Zimbabwe', ..., 8075, 0, 231]], dtype=object)

# %%
df.dtypes
# Out:
# Date_reported         object
#  Country_code         object
#  Country              object
#  WHO_region           object
#  New_cases             int64
#  Cumulative_cases      int64
#  New_deaths            int64
#  Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (67680, 8)

# %%
df.head(10)
# Out:
#   Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0    2020-01-03            AF  Afghanistan        EMRO           0
# 1    2020-01-04            AF  Afghanistan        EMRO           0
# 2    2020-01-05            AF  Afghanistan        EMRO           0
# 3    2020-01-06            AF  Afghanistan        EMRO           0
# 4    2020-01-07            AF  Afghanistan        EMRO           0
# 5    2020-01-08            AF  Afghanistan        EMRO           0
# 6    2020-01-09            AF  Afghanistan        EMRO           0
# 7    2020-01-10            AF  Afghanistan        EMRO           0
# 8    2020-01-11            AF  Afghanistan        EMRO           0
# 9    2020-01-12            AF  Afghanistan        EMRO           0
#
#     Cumulative_cases   New_deaths   Cumulative_deaths
# 0                  0            0                   0
# 1                  0            0                   0
# 2                  0            0                   0
# ...

# %%
df.tail()
# Out:
#       Date_reported  Country_code   Country  WHO_region   New_cases  \
# 67675    2020-10-12            ZW  Zimbabwe        AFRO          17
# 67676    2020-10-13            ZW  Zimbabwe        AFRO          10
# 67677    2020-10-14            ZW  Zimbabwe        AFRO          15
# 67678    2020-10-15            ZW  Zimbabwe        AFRO          19
# 67679    2020-10-16            ZW  Zimbabwe        AFRO          20
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# 67675               8011            1                 230
# 67676               8021            0                 230
# 67677               8036            0                 230
# 67678               8055            1                 231
# 67679               8075            0                 231

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67680 entries, 0 to 67679
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date_reported       67680 non-null  object
#  1    Country_code       67392 non-null  object
#  2    Country            67680 non-null  object
#  3    WHO_region         67680 non-null  object
#  4    New_cases          67680 non-null  int64
#  5    Cumulative_cases   67680 non-null  int64
#  6    New_deaths         67680 non-null  int64
#  7    Cumulative_deaths  67680 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#           New_cases   Cumulative_cases    New_deaths   Cumulative_deaths
# count  67680.000000       6.768000e+04  67680.000000        67680.000000
# mean     573.126537       4.415593e+04     16.180511         1670.899719
# std     3998.030080       3.256707e+05    108.867330        10345.688752
# min    -8261.000000       0.000000e+00   -514.000000            0.000000
# 25%        0.000000       0.000000e+00      0.000000            0.000000
# 50%        0.000000       2.050000e+02      0.000000            3.000000
# 75%       68.000000       5.127000e+03      1.000000           99.000000
# max    97894.000000       7.833851e+06   6409.000000       215199.000000

# %%
df[" Country"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 67675       Zimbabwe
# 67676       Zimbabwe
# 67677       Zimbabwe
# 67678       Zimbabwe
# 67679       Zimbabwe
# Name:  Country, Length: 67680, dtype: object

# %%
df[" Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Côte d’Ivoire',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.columns = [col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 67675       Zimbabwe
# 67676       Zimbabwe
# 67677       Zimbabwe
# 67678       Zimbabwe
# 67679       Zimbabwe
# Name: Country, Length: 67680, dtype: object

# %%
df.loc[1:4, "Country"]
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8,["Country", "New_cases" ]]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 67675       Zimbabwe
# 67676       Zimbabwe
# 67677       Zimbabwe
# 67678       Zimbabwe
# 67679       Zimbabwe
# Name: Country, Length: 67680, dtype: object

# %%
df.Country == "Kenya"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 67675    False
# 67676    False
# 67677    False
# 67678    False
# 67679    False
# Name: Country, Length: 67680, dtype: bool

# %%
df[df.Country == "Kenya"]
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 31392    2020-01-03           KE   Kenya       AFRO          0
# 31393    2020-01-04           KE   Kenya       AFRO          0
# 31394    2020-01-05           KE   Kenya       AFRO          0
# 31395    2020-01-06           KE   Kenya       AFRO          0
# 31396    2020-01-07           KE   Kenya       AFRO          0
# ...             ...          ...     ...        ...        ...
# 31675    2020-10-12           KE   Kenya       AFRO        388
# 31676    2020-10-13           KE   Kenya       AFRO         73
# 31677    2020-10-14           KE   Kenya       AFRO        320
# 31678    2020-10-15           KE   Kenya       AFRO        602
# 31679    2020-10-16           KE   Kenya       AFRO        602
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 31392                 0           0                  0
# 31393                 0           0                  0
# ...

# %%
df[df.New_deaths>1000]
# Out:
#       Date_reported Country_code                           Country WHO_region  \
# 2578     2020-10-03           AR                         Argentina       AMRO
# 7161     2020-09-08           BO  Bolivia (Plurinational State of)       AMRO
# 8203     2020-05-21           BR                            Brazil       AMRO
# 8205     2020-05-23           BR                            Brazil       AMRO
# 8206     2020-05-24           BR                            Brazil       AMRO
# ...             ...          ...                               ...        ...
# 64765    2020-09-12           US          United States of America       AMRO
# 64766    2020-09-13           US          United States of America       AMRO
# 64771    2020-09-18           US          United States of America       AMRO
# 64778    2020-09-25           US          United States of America       AMRO
# 64785    2020-10-02           US          United States of America       AMRO
#
# ...

# %%
df.loc[df.New_deaths>1000, ['New_deaths', 'Country']]
# Out:
#        New_deaths                           Country
# 2578         3351                         Argentina
# 7161         1610  Bolivia (Plurinational State of)
# 8203         1179                            Brazil
# 8205         1188                            Brazil
# 8206         1001                            Brazil
# ...           ...                               ...
# 64765        1078          United States of America
# 64766        1022          United States of America
# 64771        1204          United States of America
# 64778        1125          United States of America
# 64785        1024          United States of America
#
# [219 rows x 2 columns]

# %%
df.loc[(df.New_deaths>5) & (df.Country_code == "KE"), ["Country", "New_cases", "New_deaths"]]
# Out:
#       Country  New_cases  New_deaths
# 31560   Kenya        213          10
# 31582   Kenya        473           8
# 31585   Kenya        189          12
# 31587   Kenya        461           7
# 31588   Kenya        421           8
# 31591   Kenya        603           9
# 31593   Kenya        397          12
# 31594   Kenya        637          10
# 31596   Kenya        667          11
# 31599   Kenya       1332           7
# 31600   Kenya        606          14
# 31601   Kenya        544          12
# 31602   Kenya        788          14
# 31603   Kenya        723          16
# 31604   Kenya        727          23
# 31606   Kenya        544          13
# 31607   Kenya        605           6
# 31609   Kenya        538           8
# 31610   Kenya        727          14
# 31614   Kenya        497          15
# 31615   Kenya        679          18
# 31618   Kenya        515           7
# 31620   Kenya        245           8
# 31622   Kenya        379          19
# ...

# %%
df.loc[df.Country_code == "KE", ['New_cases']].max()
# Out:
# New_cases    1332
# dtype: int64

# %%
df.loc[df.Country_code == "KE", ['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code == "KE", ['New_cases']].sum()
# Out:
# New_cases    43143
# dtype: int64

# %%
df.loc[df.Country_code == "KE", ['Cumulative_deaths']].max()
# Out:
# Cumulative_deaths    805
# dtype: int64

# %%
df.New_cases.idxmax()
# Out:
# 27906

# %%
df.loc[df.New_cases.idxmax(),['Date_reported', 'Country_code', 'Country', 'WHO_region','New_cases', 'Cumulative_cases','New_deaths','Cumulative_deaths']]
# Out:
# Date_reported        2020-09-17
# Country_code                 IN
# Country                   India
# WHO_region                SEARO
# New_cases                 97894
# Cumulative_cases        5118253
# New_deaths                 1132
# Cumulative_deaths         83198
# Name: 27906, dtype: object

# %%
df[df.New_deaths < 0]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 246      2020-09-05           AF               Afghanistan       EMRO
# 790      2020-08-04           DZ                   Algeria       AFRO
# 1716     2020-10-05           AO                    Angola       AFRO
# 3321     2020-06-04           AU                 Australia       WPRO
# 4272     2020-08-30           BS                   Bahamas       AMRO
# 4533     2020-08-03           BH                   Bahrain       EMRO
# 9408     2020-07-13           BF              Burkina Faso       AFRO
# 13118    2020-06-09           CG                     Congo       AFRO
# 14625    2020-08-15           CU                      Cuba       AMRO
# 15448    2020-07-05           CZ                   Czechia       EURO
# 15449    2020-07-06           CZ                   Czechia       EURO
# 16259    2020-05-13           DK                   Denmark       EURO
# ...

# %%
df["pct_cases"] = (df['New_cases']/df['Cumulative_cases'])*100
df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-03           AF  Afghanistan       EMRO          0
# 1        2020-01-04           AF  Afghanistan       EMRO          0
# 2        2020-01-05           AF  Afghanistan       EMRO          0
# 3        2020-01-06           AF  Afghanistan       EMRO          0
# 4        2020-01-07           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 67675    2020-10-12           ZW     Zimbabwe       AFRO         17
# 67676    2020-10-13           ZW     Zimbabwe       AFRO         10
# 67677    2020-10-14           ZW     Zimbabwe       AFRO         15
# 67678    2020-10-15           ZW     Zimbabwe       AFRO         19
# 67679    2020-10-16           ZW     Zimbabwe       AFRO         20
#
#        Cumulative_cases  New_deaths  Cumulative_deaths  pct_cases
# 0                     0           0                  0        NaN
# ...
